# %%
import pandas as pd
import numpy as np
import seaborn as sn
from tqdm import tqdm
import urllib.parse
import grequests

# %%
clean = pd.read_excel('./July.xlsx',sheet_name='all')

# %%
clean.head()
# Out:
#    Order      Source       ChemicalName  C18RT  PFPRT  \
# 0      1  analyticon     Chebuloside II  3.647  3.378
# 1      2  analyticon  Nigaichigoside F1  3.635  3.403
# 2      3  analyticon   Arjunglucoside I  3.869  3.410
# 3      4  analyticon     Ilexsaponin A1  4.800  4.360
# 4      5  analyticon       CID 45783224  4.544  4.171
#
#                       INCHIKEY           Short  \
# 0  DZVIFFMYEULLBY-NSOPSRGASA-N  DZVIFFMYEULLBY
# 1  WKKBYJLXSKPKSC-VBXFOCAZSA-N  WKKBYJLXSKPKSC
# 2  CMZFNIMQBCBHEX-KXLFRROQSA-N  CMZFNIMQBCBHEX
# 3  AWFZJSUJFSUBQU-FZEZCDDVSA-N  AWFZJSUJFSUBQU
# 4  KISJFUMXCJBLJV-ZZDFEWANSA-N  KISJFUMXCJBLJV
#
#                                      CanonicalSMILES
# 0  CC1(CCC2(CCC3(C(=CCC4C3(CC(C5C4(CC(C(C5(C)CO)O...
# 1  CC1CCC2(CCC3(C(=CCC4C3(CCC5C4(CC(C(C5(C)CO)O)O...
# 2  CC1(CCC2(CCC3(C(=CCC4C3(CCC5C4(CC(C(C5(C)CO)O)...
# 3  CC1CCC2(CCC3(C(=CCC4C3(CCC5C4(CCC(C5(C)C(=O)O)...
# 4  CC(=C)CCC(=O)C(C)(C1C(CC2(C1(CC(=O)C3(C2CC=C4C...

# %% [markdown]
# ## Check duplicates

# %% [markdown]
# ### C18

# %%
for column in ['C18RT']:
    clean2 = clean[clean[column].notnull()]
    dup = clean2['INCHIKEY'][clean2.duplicated(['INCHIKEY'],keep=False)]
    dup = dup.unique()
    diff = []
    for key in dup:
        value = clean[column][clean['INCHIKEY']==key]
        diff.append(value.max() - value.min())
    
    hist = sn.displot(diff,binwidth=0.1)
    hist.set(xlabel=column)
    
    df = pd.DataFrame({'INCHIKEY':dup, 'diff':diff})
    mean = df['diff'].mean()
df[df['diff']>0.3]
# Out:
#                         INCHIKEY   diff
# 3    BTCICADMSGBCKA-UHFFFAOYSA-N  0.312
# 9    PVHUKALHRBPQNM-BSWSSELBSA-N  1.203
# 17   SRCSHETVEHQXLC-RBISFHTESA-N  0.800
# 23   LHZKHFYNHHUDEF-UHFFFAOYSA-N  0.311
# 25   YSFNIMJWUPAQKC-XZOQMXBNSA-N  1.143
# 26   XFAGPJNDBTUJPH-PJQSMRKJSA-N  2.683
# 31   FFMVHFPLIIYYNC-UHFFFAOYSA-N  1.111
# 44   RNQBLQALVMHBKH-UHFFFAOYSA-N  0.600
# 58   ULSUXBXHSYSGDT-UHFFFAOYSA-N  0.360
# 60   OEWCQSJKSNWJTH-UHFFFAOYSA-N  1.866
# 61   CWVRJTMFETXNAD-JUHZACGLSA-N  0.348
# 63   IKMDFBPHZNJCSN-UHFFFAOYSA-N  3.340
# 81   HVQAJTFOCKOKIN-UHFFFAOYSA-N  0.437
# 88   OCINXEZVIIVXFU-UHFFFAOYSA-N  6.122
# 99   RWSXRVCMGQZWBV-WDSKDSINSA-N  0.600
# 104  KXGVEGMKQFWNSR-LLQZFEROSA-N  0.561
# 110  WVTKBKWTSCPRNU-KYJUHHDHSA-N  3.129
# 117  QANMHLXAZMSUEX-UHFFFAOYSA-N  0.405
# 119  QYSXJUFSXHHAJI-YRZJJWOYSA-N  0.954

# %%
# Out:
#                         INCHIKEY   diff
# 2    ZOEFIRUNMVHSJA-XXZDZOCTSA-N  1.150
# 4    DNXHEGUUPJUMQT-CBZIJGRNSA-N  0.492
# 5    BTCICADMSGBCKA-UHFFFAOYSA-N  2.480
# 6    NPDSHTNEKLQQIJ-SIGMCMEVSA-N  0.978
# 11   OGTDCWCKOKLYSK-UHFFFAOYSA-N  3.103
# ..                           ...    ...
# 127  OVBPIULPVIDEAO-LBPRGKRZSA-N  0.369
# 129  IXORZMNAPKEEDV-OBDJNFEBSA-N  0.345
# 130  WUBBRNOQWQTFEX-UHFFFAOYSA-N  0.324
# 135  AGOYDEPGAOXOCK-KCBOHYOISA-N  0.398
# 138  QEVHRUUCFGRFIF-MDEJGZGSSA-N  0.630
#
# [82 rows x 2 columns]

# %% [markdown]
# ### PFP
#
# PFP result is worse than C18;
# 1) more duplicates
# 2) more difference > 0.3 min

# %%
for column in ['PFPRT']:
    clean2 = clean[clean[column].notnull()]
    dup = clean2['INCHIKEY'][clean2.duplicated(['INCHIKEY'],keep=False)]
    dup = dup.unique()
    diff = []
    for key in dup:
        value = clean[column][clean['INCHIKEY']==key]
        diff.append(value.max() - value.min())
    
    hist = sn.displot(diff,binwidth=0.1)
    hist.set(xlabel=column)
    
    df = pd.DataFrame({'INCHIKEY':dup, 'diff':diff})
    mean = df['diff'].mean()
df[df['diff']>0.3]
# Out:
#                         INCHIKEY   diff
# 2    ZOEFIRUNMVHSJA-XXZDZOCTSA-N  1.150
# 4    DNXHEGUUPJUMQT-CBZIJGRNSA-N  0.492
# 5    BTCICADMSGBCKA-UHFFFAOYSA-N  2.480
# 6    NPDSHTNEKLQQIJ-SIGMCMEVSA-N  0.978
# 11   OGTDCWCKOKLYSK-UHFFFAOYSA-N  3.103
# ..                           ...    ...
# 127  OVBPIULPVIDEAO-LBPRGKRZSA-N  0.369
# 129  IXORZMNAPKEEDV-OBDJNFEBSA-N  0.345
# 130  WUBBRNOQWQTFEX-UHFFFAOYSA-N  0.324
# 135  AGOYDEPGAOXOCK-KCBOHYOISA-N  0.398
# 138  QEVHRUUCFGRFIF-MDEJGZGSSA-N  0.630
#
# [82 rows x 2 columns]

# %% [markdown]
# ## Get classifications

# %% [markdown]
# ### Remove null SMILES

# %%
clean = clean[clean['CanonicalSMILES'].notnull()]
clean = clean.drop_duplicates(subset=['INCHIKEY'])

# %%
clean2d = clean.drop_duplicates(subset=['Short'])
# Out:
#       Order      Source          ChemicalName  C18RT  PFPRT  \
# 0         1  analyticon        Chebuloside II  3.647  3.378
# 1         2  analyticon     Nigaichigoside F1  3.635  3.403
# 2         3  analyticon      Arjunglucoside I  3.869  3.410
# 3         4  analyticon        Ilexsaponin A1  4.800  4.360
# 4         5  analyticon          CID 45783224  4.544  4.171
# ...     ...         ...                   ...    ...    ...
# 6252    995         FDA            Pranlukast  6.150  5.717
# 6253    996         FDA           Pranoprofen  4.048  3.750
# 6254    997         FDA          Praziquantel  4.950  4.329
# 6255    998         FDA          Prednisolone  3.845  3.500
# 6256    999         FDA  Prednisolone acetate  4.570  4.130
#
#                          INCHIKEY           Short  \
# 0     DZVIFFMYEULLBY-NSOPSRGASA-N  DZVIFFMYEULLBY
# 1     WKKBYJLXSKPKSC-VBXFOCAZSA-N  WKKBYJLXSKPKSC
# 2     CMZFNIMQBCBHEX-KXLFRROQSA-N  CMZFNIMQBCBHEX
# 3     AWFZJSUJFSUBQU-FZEZCDDVSA-N  AWFZJSUJFSUBQU
# 4     KISJFUMXCJBLJV-ZZDFEWANSA-N  KISJFUMXCJBLJV
# ...                           ...             ...
# 6252  NBQKINXMPLXUET-UHFFFAOYSA-N  NBQKINXMPLXUET
# 6253  TVQZAMVBTVNYLA-UHFFFAOYSA-N  TVQZAMVBTVNYLA
# 6254  FSVJFNAIGNNGKK-UHFFFAOYSA-N  FSVJFNAIGNNGKK
# 6255  OIGNJSKKLXVSLS-VWUMJDOOSA-N  OIGNJSKKLXVSLS
# 6256  LRJOMUJRLNCICJ-JZYPGELDSA-N  LRJOMUJRLNCICJ
#
#                                         CanonicalSMILES
# 0     CC1(CCC2(CCC3(C(=CCC4C3(CC(C5C4(CC(C(C5(C)CO)O...
# 1     CC1CCC2(CCC3(C(=CCC4C3(CCC5C4(CC(C(C5(C)CO)O)O...
# 2     CC1(CCC2(CCC3(C(=CCC4C3(CCC5C4(CC(C(C5(C)CO)O)...
# 3     CC1CCC2(CCC3(C(=CCC4C3(CCC5C4(CCC(C5(C)C(=O)O)...
# 4     CC(=C)CCC(=O)C(C)(C1C(CC2(C1(CC(=O)C3(C2CC=C4C...
# ...                                                 ...
# 6252  C1=CC=C(C=C1)CCCCOC2=CC=C(C=C2)C(=O)NC3=CC=CC4...
# 6253           CC(C1=CC2=C(C=C1)OC3=C(C2)C=CC=N3)C(=O)O
# 6254         C1CCC(CC1)C(=O)N2CC3C4=CC=CC=C4CCN3C(=O)C2
# 6255   CC12CC(C3C(C1CCC2(C(=O)CO)O)CCC4=CC(=O)C=CC34C)O
# 6256  CC(=O)OCC(=O)C1(CCC2C1(CC(C3C2CCC4=CC(=O)C=CC3...
#
# [5802 rows x 8 columns]

# %%
clean2d = clean2d[clean2d['C18RT'].isnull()&clean2d['PFPRT'].isnull()]

# %%
clean2d
# Out:
#       Order      Source                                       ChemicalName  \
# 31       32  analyticon  NCGC00168887-02_C21H26O6_2-[6-Acetyl-3-(isobut...
# 40       42  analyticon  10-[(6-Carboxy-4-{[4,5-dihydroxy-6-(hydroxymet...
# 47       49  analyticon    Cyanidin 3-xylosyl(feruloylglucosyl)galactoside
# 128     131  analyticon  3,6-Dibenzyl-9-[(2,3-diamino-1,2-dihydroindol-...
# 146     149  analyticon          2,3-Dihydroxypropyl 12-methyltridecanoate
# ...     ...         ...                                                ...
# 6211    962         FDA                                    4-Methoxyphenol
# 6213    964         FDA                                          Metformin
# 6215    966         FDA                                        Methenamine
# 6240    985         FDA                                           Nystatin
# 6248    990         FDA                                    Oxytetracycline
#
#       C18RT  PFPRT                     INCHIKEY           Short  \
# 31      NaN    NaN  CPDCJXCECPCPNL-UHFFFAOYSA-N  CPDCJXCECPCPNL
# 40      NaN    NaN  YUEGUTWXPBCZPT-UHFFFAOYSA-N  YUEGUTWXPBCZPT
# 47      NaN    NaN  MUQNMJSHMPEZCV-JHCRVGSQSA-O  MUQNMJSHMPEZCV
# 128     NaN    NaN  KNSDITCTAHCCEB-UHFFFAOYSA-N  KNSDITCTAHCCEB
# 146     NaN    NaN  ZGNRVILZVRTZON-UHFFFAOYSA-N  ZGNRVILZVRTZON
# ...     ...    ...                          ...             ...
# 6211    NaN    NaN  NWVVVBRKAWDGAB-UHFFFAOYSA-N  NWVVVBRKAWDGAB
# 6213    NaN    NaN  XZWYZXLIPXDOLR-UHFFFAOYSA-N  XZWYZXLIPXDOLR
# 6215    NaN    NaN  VKYKSIONXSXAKP-UHFFFAOYSA-N  VKYKSIONXSXAKP
# 6240    NaN    NaN  VQOXZBDYSJBXMA-RKEBNKJGSA-N  VQOXZBDYSJBXMA
# 6248    NaN    NaN  OWFJMIVZYSDULZ-PXOLEDIWSA-N  OWFJMIVZYSDULZ
#
#                                         CanonicalSMILES
# 31    CC(C)C(=O)OCC(=C)C1C(C2=C(O1)C=C(C=C2)C(=O)C)O...
# 40    CC1C(C(C(C(O1)OC2C(C(C(OC2OC3C(C(OC(C3OC4C(C(C...
# 47    COC1=C(C=CC(=C1)C=CC(=O)OCC2C(C(C(C(O2)OCC3C(C...
# 128   C1=CC=C(C=C1)CC2C(=O)NC(C(=O)NC(C(=O)N2)CC3=CC...
# 146                        CC(C)CCCCCCCCCCC(=O)OCC(CO)O
# ...                                                 ...
# 6211                                   COC1=CC=C(C=C1)O
# 6213                                  CN(C)C(=N)N=C(N)N
# 6215                                 C1N2CN3CN1CN(C2)C3
# 6240  CC1C=CC=CCCC=CC=CC=CC=CC(CC2C(C(CC(O2)(CC(C(CC...
# 6248  CC1(C2C(C3C(C(=O)C(=C(C3(C(=O)C2=C(C4=C1C=CC=C...
#
# [747 rows x 8 columns]

# %% [markdown]
# ### This gives us ~5100 compounds with RT, but we only got ~4400 in msp.

# %% [markdown]
# ### Classyfire
# API: https://gnps-structure.ucsd.edu/classyfire?smiles=<smiles string\>

# %% [markdown]
# ### NP Classifier
# API: http://192.168.128.240:6541/classify?smiles=<smiles string\>

# %%
# SERVER_URL = "https://npclassifier.ucsd.edu/"
def query(smiles_list,SERVER_URL):
    all_urls = []
    for smiles in smiles_list:
        request_url = "{}/classify?smiles={}".format(SERVER_URL, urllib.parse.quote(smiles))
        all_urls.append(request_url)
    rs = (grequests.get(u) for u in all_urls)
    responses = grequests.map(rs, size=20)
    return responses

SERVER_URL = "http://192.168.128.240:6541/"
smiles_list = clean["CanonicalSMILES"].to_list()
responses = query(smiles_list, SERVER_URL)

# %%
# convert results to df
C = []
pathway = []
SC = []
glyco = []
i=0
for r in responses:
    try:
        test = r.json() 
    except:
        C.append('NA')              
        pathway.append('NA')
        SC.append('NA')
        glyco.append('NA')
        continue
    C.append(test['class_results'])              
    pathway.append(test['pathway_results'])
    SC.append(test['superclass_results'])
    glyco.append(test['isglycoside'])
    i += 1
    
df = pd.DataFrame({'SMILES':smiles_list,'pathway_results':pathway, 'superclass_results':SC, 'class_results':C, 'isglycoside':glyco })

# %%
df['class_results'] = df['class_results'].apply(lambda x: ''.join(x))
df['pathway_results'] = df['pathway_results'].apply(lambda x: ''.join(x))
df['superclass_results'] = df['superclass_results'].apply(lambda x: ''.join(x))

# %%
df.head()
# Out:
#                                               SMILES pathway_results  \
# 0  CC1(CCC2(CCC3(C(=CCC4C3(CC(C5C4(CC(C(C5(C)CO)O...      Terpenoids
# 1  CC1CCC2(CCC3(C(=CCC4C3(CCC5C4(CC(C(C5(C)CO)O)O...      Terpenoids
# 2  CC1(CCC2(CCC3(C(=CCC4C3(CCC5C4(CC(C(C5(C)CO)O)...      Terpenoids
# 3  CC1CCC2(CCC3(C(=CCC4C3(CCC5C4(CCC(C5(C)C(=O)O)...      Terpenoids
# 4  CC(=C)CCC(=O)C(C)(C1C(CC2(C1(CC(=O)C3(C2CC=C4C...      Terpenoids
#
#   superclass_results                         class_results isglycoside
# 0      Triterpenoids                Oleanane triterpenoids        True
# 1      Triterpenoids  Ursane and Taraxastane triterpenoids        True
# 2      Triterpenoids                Oleanane triterpenoids        True
# 3      Triterpenoids  Ursane and Taraxastane triterpenoids        True
# 4      Triterpenoids             Cucurbitane triterpenoids        True

# %%
df[df['isglycoside'] == 'NA']
# Out:
#                                                  SMILES pathway_results  \
# 4042  C[C@@H]1[C@H](C[C@@H]([C@H](O1)OC2[C@@H]([C@H]...              NA
# 4051       CC(=C)[C@H]1CCC(=CC1)CO, CC(=C)C1CCC(=CC1)CO              NA
# 5323  C[C@]12CC[C@@H](C1(C)C)CC2=O, CC1(C2CCC1(C(=O)...              NA
# 5353  C[C@@H]([C@@H](C1=CC=CC=C1)O)NC, C[C@@H]([C@@H...              NA
# 5391  C[C@]12CC[C@H]3[C@H]([C@@H]1C[C@H]([C@@H]2OC(=...              NA
# 5496  CC[C@@H]1[C@@]([C@@H]([C@H](C(=O)[C@@H](C[C@@]...              NA
# 5609  CC1=C(N=C(N=C1N)[C@H](CC(=O)N)NC[C@H](C(=O)N)N...              NA
#
#      superclass_results class_results isglycoside
# 4042                 NA            NA          NA
# 4051                 NA            NA          NA
# 5323                 NA            NA          NA
# 5353                 NA            NA          NA
# 5391                 NA            NA          NA
# 5496                 NA            NA          NA
# 5609                 NA            NA          NA

# %%
df['class_results'] = df['class_results'].apply(lambda x: ''.join(x))
df['pathway_results'] = df['pathway_results'].apply(lambda x: ''.join(x))
df['superclass_results'] = df['superclass_results'].apply(lambda x: ''.join(x))

# %%
df.iloc[20]
# Out:
# SMILES                CCC(C)C=C(C)C=CC(=O)CC1=CC(=C(C(=C1C=O)O)C)O
# pathway_results                                        Polyketides
# superclass_results                            Aromatic polyketides
# class_results
# isglycoside                                                  False
# Name: 20, dtype: object

# %%
sn.histplot(data=df, x="pathway_results")
# Out:
# <AxesSubplot:xlabel='pathway_results', ylabel='Count'>

# %%
type(df.iloc[20]['class_results'])
# Out:
# list
